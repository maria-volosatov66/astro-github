# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
Magnitude = array([8.23,5.46,2.87,6.93,8.83,3.64,3.88,12.05,9.29,8.13,5.45,5.46,7.9,8.58,6.43,7.66,7.77,7.72,8.8,7.97])
#Temperature = array([8.31,15.2,15.2,9.6,7.35,15.2,15.2,5.66,6.7,9.6,15.2,15.2,7.35,7.35,15.2,9.6,9.6,5.24,5.24,8.31])*1e3
Spec = array([5,3,3,4,6,3,3,9,7,4,3,3,6,6,3,4,4,10,10,5])


print(Magnitude)
#figure(figsize=[15,6])
ff = logspace(1,6,100)
Gtheo = 20*log10(abs(Magnitude))

subplot(1,2,1)
semilogx(Temperature,Magnitude,'o')
legend(['Theory','Experiment'], loc=4)
grid(1)
ylim([-10,10000])
xlabel('Frequency [Hz]')
ylabel('Gain [dB]')
title('Bode Plot of Low Pass RL Filter-Amplitude Transfer Function')
# Out:
# [  8.23   5.46   2.87   6.93   8.83   3.64   3.88  12.05   9.29   8.13
#    5.45   5.46   7.9    8.58   6.43   7.66   7.77   7.72   8.8    7.97]
# Text(0.5,1,'Bode Plot of Low Pass RL Filter-Amplitude Transfer Function')

# %%
len(Magnitude)
print(len(Magnitude))
# Out:
# 20

# %%
# log

#plt.plot(Temperature, Magnitude, 'o')

plt.plot(Spec,Magnitude, linestyle='none', marker='.', markersize=10, markerfacecolor='red',markeredgecolor='black')
plt.title('H-R Diagram')
plt.grid(True)
grid(1)
xlim(0,15)
my_xticks=['A5','B5','B5','A0','F0','B5','B5','G5','F5','A0','B5','B5','F0','F0','B5','A0','A0','K0','K0','A5']
plt.xticks(Spec, my_xticks)
xlabel('Spectral Type')
ylim(0,15)
ylabel('Magnitude')

len(Magnitude)
print(len(Magnitude))
# Out:
# 20
